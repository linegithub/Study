# %% [markdown]
# <a href="https://colab.research.google.com/github/linegithub/Study/blob/master/cap1merc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import xlrd
import numpy as np
import matplotlib.pyplot as fig

# %%
pegueioarquivo = xlrd.open_workbook('petrobrastestzin.xlsx')

# %%
pegueiaplanilha = pegueioarquivo.sheet_by_name('Página1')

# %%
pegueiacoluna = pegueiaplanilha.col_values(0)
pegueiacoluna

# %%
virouarray = np.array(pegueiacoluna)
virouarray

# %%
virouarray.dtype

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
retornofinanceiro = (virouarray[1:20] - virouarray[0:19]) / virouarray[0:19]
retornofinanceiro

# %%
t = np.arange(0,19)
t

# %%
fig.title('Retorno Financeiro')
fig.xlabel('tempo')
fig.ylabel('retorno')
fig.plot(t,retornofinanceiro)

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
import math
import statistics as st

# %%
media = st.mean(retornofinanceiro)
media

# %%
desviopadrao = st.pstdev(retornofinanceiro)
desviopadrao

# %%
n = len(retornofinanceiro)
n

# %%
otimista = media + ((2*desviopadrao)/math.sqrt(n))
pessimista = media - ((2*desviopadrao)/math.sqrt(n))
print(otimista,pessimista)

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %%
z = np.arange(0,20)
z

# %%
fig.subplot(211)
fig.plot(z, virouarray)
fig.subplot(212); fig.plot(t, retornofinanceiro)
